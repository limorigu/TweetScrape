# %% [markdown]
# * Author: Limor Gultchin
# * Date: Oct 13th, 2023
# * Goal: Scrape tweets of target user using Twitter's official API

# %%
import requests
import os
import json
import pandas as pd

# TODO: specify bearer token
# Option 1: To set your environment variables in your terminal run the following line:
# export 'BEARER_TOKEN'='<your_bearer_token>'
# bearer_token = os.environ.get("BEARER_TOKEN")
# OR 
# Option 2: replace directly below 
bearer_token = ''
# TODO: specify user_id of target twitter handle
user_id = np.nan

def create_url(user_id):
    # Replace with user ID below
    user_id = user_id
    return "https://api.twitter.com/2/users/{}/tweets".format(user_id)


def get_params(start_time, end_time):
    # Tweet fields are adjustable.
    # Options include:
    # attachments, author_id, context_annotations,
    # conversation_id, created_at, entities, geo, id,
    # in_reply_to_user_id, lang, non_public_metrics, organic_metrics,
    # possibly_sensitive, promoted_metrics, public_metrics, referenced_tweets,
    # source, text, and withheld
    return {"tweet.fields": "created_at",
            "start_time": start_time,
            "end_time": end_time,
            "max_results": 100
            }


def bearer_oauth(r):
    """
    Method required by bearer token authentication.
    """

    r.headers["Authorization"] = f"Bearer {bearer_token}"
    r.headers["User-Agent"] = "v2UserTweetsPython"
    return r


def connect_to_endpoint(url, params):
    response = requests.request("GET", url, auth=bearer_oauth, params=params)
    print(response.status_code)
    if response.status_code != 200:
        raise Exception(
            "Request returned an error: {} {}".format(
                response.status_code, response.text
            )
        )
    return response.json()


def main(start_time, end_time, user_id):
    url = create_url(user_id)
    params = get_params(start_time, end_time)
    json_response = connect_to_endpoint(url, params)
    print(json.dumps(json_response, indent=4, sort_keys=True, ensure_ascii=False))
    return json_response

# %%
dfs = []
times = [("2023-10-07T04:30:00+00:00", "2023-10-07T12:30:00+00:00"), 
         ("2023-10-07T12:30:01+00:00", "2023-10-07T20:30:00+00:00"), 
         ("2023-10-07T20:30:01+00:00", "2023-10-08T04:30:00+00:00"),
         ("2023-10-08T04:30:01+00:00", "2023-10-08T12:30:00+00:00"),
         ("2023-10-08T12:30:01+00:00", "2023-10-08T20:30:00+00:00"),
         ("2023-10-08T20:30:01+00:00", "2023-10-09T04:30:00+00:00")]
for time in times:
    print(f"processing {time}")
    response = main(time[0], time[1], user_id)
    df = pd.DataFrame(response['data'])
    df.to_csv(f"id{user_id}_{time[0][:19]}_{time[1][:19]}.csv")
    dfs.append(df)
    
# concatenate all dfs
concatenated_df = pd.concat(dfs)
concatenated_df.to_csv(f"id_{user_id}_all.csv")
# Out:
# processing ('2023-10-07T04:30:00+00:00', '2023-10-07T12:30:00+00:00')
# 200
# {
#     "data": [
#         {
#             "created_at": "2023-10-07T12:28:38.000Z",
#             "edit_history_tweet_ids": [
#                 "1710633227247841428"
#             ],
#             "id": "1710633227247841428",
#             "text": "אחד השכנים מצלם. כאמור נראה צהל אבל בגלל שלא מתקשרים למספר מדווח אין לנו איך לדעת https://t.co/ojEIxWHkcy"
#         },
#         {
#             "created_at": "2023-10-07T12:27:28.000Z",
#             "edit_history_tweet_ids": [
#                 "1710632933680177521"
#             ],
#             "id": "1710632933680177521",
#             "text": "ניסן מדווח https://t.co/I34VMO0sk0"
#         },
#         {
#             "created_at": "2023-10-07T12:26:47.000Z",
#             "edit_history_tweet_ids": [
#                 "1710632764880433635"
#             ],
#             "id": "1710632764880433635",
#             "text": "שריקות בחוץ"
#         },
#         {
#             "created_at": "2023-10-07T12:21:57.000Z",
#             "edit_history_tweet_ids": [
#                 "1710631547949269413"
#             ],
#             "id": "1710631547949269413",
#             "text": "ניסן מדווח מהשטח https://t.co/HQdUq5U1TY"
#         },
#         {
#             "created_at": "2023-10-07T12:19:11.000Z",
#             "edit_history_tweet_ids": [
#                 "1710630850386170340"
#             ],
#             "id": "1710630850386170340",
#             "text": "יש אנשים עם מדים בחוץ. לא מבינים אם זה חיילינו שבאו בגלל הפנייה או מחבלים מחופשים. מה הקטע לא להתקשר חזרה למספר המדווח?"
#         },
#         {
#             "created_at": "2023-10-07T12:17:19.000Z",
#             "edit_history_tweet_ids": [
#                 "1710630379936260428"
#             ],
#             "id": "1710630379936260428",
#             "text": "רעש של בום"
#         },
#         {
#             "created_at": "2023-10-07T12:15:38.000Z",
#             "edit_history_tweet_ids": [
#                 "1710629959050428698"
#             ],
#             "id": "1710629959050428698",
#             "text": "אם יש למישהו קשר לכוחות הביטחון או משהו מאוד נשמח כי ובכן נראה שיש מחבלים בחוץ, דיווחנו ואף אחד לא בא"
#         },
#         {
#             "created_at": "2023-10-07T12:14:20.000Z",
#             "edit_history_tweet_ids": [
#                 "1710629630728638617"
#             ],
#             "id": "1710629630728638617",
#             "text": "החבוב עם המצלמה מדווח על שני אנשים שהולכים לכיוון ההפוך"
#         },
#         {
#             "created_at": "2023-10-07T12:12:45.000Z",
#             "edit_history_tweet_ids": [
#                 "1710629231284167042"
#             ],
#             "id": "1710629231284167042",
#             "text": "מצב העניינים https://t.co/mi0mqMOHyW"
#         },
#         {
#             "created_at": "2023-10-07T12:11:46.000Z",
#             "edit_history_tweet_ids": [
#                 "1710628984185143517"
#             ],
#             "id": "1710628984185143517",
#             "text": "וכמובן: ניסן עשה קקי והטיטולים בחוץ"
#         },
#         {
#             "created_at": "2023-10-07T12:10:19.000Z",
#             "edit_history_tweet_ids": [
#                 "1710628617896534284"
#             ],
#             "id": "1710628617896534284",
#             "text": "אחד השכנים עם מצלמה כלפי הרחוב. מדווח שראה אנשים ברחוב"
#         },
#         {
#             "created_at": "2023-10-07T12:07:02.000Z",
#             "edit_history_tweet_ids": [
#                 "1710627793984168009"
#             ],
#             "id": "1710627793984168009",
#             "text": "@Taltalona אי אפשר פה. הדלת בנויה אחרת"
#         },
#         {
#             "created_at": "2023-10-07T12:06:09.000Z",
#             "edit_history_tweet_ids": [
#                 "1710627570704646467"
#             ],
#             "id": "1710627570704646467",
#             "text": "דיווח על מחבלים בגג בית סמוך אלינו"
#         },
#         {
#             "created_at": "2023-10-07T12:02:57.000Z",
#             "edit_history_tweet_ids": [
#                 "1710626764978864572"
#             ],
#             "id": "1710626764978864572",
#             "text": "תמונצ: עושים תורנות הישענות על הידית https://t.co/unA3iECYr8"
#         },
#         {
#             "created_at": "2023-10-07T11:59:34.000Z",
#             "edit_history_tweet_ids": [
#                 "1710625913656795495"
#             ],
#             "id": "1710625913656795495",
#             "text": "בינתיים שקט למעט צרורות ירי מבחוץ. אבל אין לנו אומץ לצאת החוצה"
#         },
#         {
#             "created_at": "2023-10-07T11:58:40.000Z",
#             "edit_history_tweet_ids": [
#                 "1710625689727049872"
#             ],
#             "id": "1710625689727049872",
#             "text": "כן, לראות את איתמר בן גביר יושב בראש השולחן זה מה שהייתי צריך כדי להרגע"
#         },
#         {
#             "created_at": "2023-10-07T11:58:12.000Z",
#             "edit_history_tweet_ids": [
#                 "1710625569749061669"
#             ],
#             "id": "1710625569749061669",
#             "text": "תְּפִלָּה לְעָנִי כִי יַעֲטֹף וְלִפְנֵי ה' יִשְׁפֹּךְ שִׂיחוֹ:\n ה' שִׁמְעָה תְפִלָּתִי וְשַׁוְעָתִי אֵלֶיךָ תָבוֹא:\n אַל תַּסְתֵּר פָּנֶיךָ מִמֶּנִּי בְּיוֹם צַר לִי\nהַטֵּה אֵלַי אָזְנֶךָ בְּיוֹם אֶקְרָא מַהֵר עֲנֵנִי"
#         },
#         {
#             "created_at": "2023-10-07T11:55:09.000Z",
#             "edit_history_tweet_ids": [
#                 "1710624801608388645"
#             ],
#             "id": "1710624801608388645",
#             "text": "מצאנו מספר זמין. מדווחים"
#         },
#         {
#             "created_at": "2023-10-07T11:54:33.000Z",
#             "edit_history_tweet_ids": [
#                 "1710624653163606021"
#             ],
#             "id": "1710624653163606021",
#             "text": "גם שכנים מדווחים על רעש. שמענו צרורות ירי"
#         },
#         {
#             "created_at": "2023-10-07T11:53:24.000Z",
#             "edit_history_tweet_ids": [
#                 "1710624360350822579"
#             ],
#             "id": "1710624360350822579",
#             "text": "(אבל הוא רואה רק חצי גג)"
#         },
#         {
#             "created_at": "2023-10-07T11:53:08.000Z",
#             "edit_history_tweet_ids": [
#                 "1710624293401333898"
#             ],
#             "id": "1710624293401333898",
#             "text": "100  ו106 לא זמינים. בינתיים שכן עלה ואמר שהגג ריק"
#         },
#         {
#             "created_at": "2023-10-07T11:51:55.000Z",
#             "edit_history_tweet_ids": [
#                 "1710623987359744205"
#             ],
#             "id": "1710623987359744205",
#             "text": "@zamird91 סליחה השקד 10"
#         },
#         {
#             "created_at": "2023-10-07T11:51:39.000Z",
#             "edit_history_tweet_ids": [
#                 "1710623920947167371"
#             ],
#             "id": "1710623920947167371",
#             "text": "@zamird91 השקד 15"
#         },
#         {
#             "created_at": "2023-10-07T11:50:24.000Z",
#             "edit_history_tweet_ids": [
#                 "1710623607687196876"
#             ],
#             "id": "1710623607687196876",
#             "text": "נשמע כמו מישהו על הגג/מרפסת. ננעלנו ומתקשרים למשטרה"
#         },
#         {
#             "created_at": "2023-10-07T11:49:41.000Z",
#             "edit_history_tweet_ids": [
#                 "1710623426149257564"
#             ],
#             "id": "1710623426149257564",
#             "text": "רעש מלמעלה."
#         },
#         {
#             "created_at": "2023-10-07T11:46:27.000Z",
#             "edit_history_tweet_ids": [
#                 "1710622614606004470"
#             ],
#             "id": "1710622614606004470",
#             "text": "עשינו גיחה למקרר לשחד את הגורה עם שלוק https://t.co/mbDELvU6sc"
#         },
#         {
#             "created_at": "2023-10-07T11:45:54.000Z",
#             "edit_history_tweet_ids": [
#                 "1710622476764373369"
#             ],
#             "id": "1710622476764373369",
#             "text": "שמענו צרור של ירי כבד (מאג/מק\"כ וואטאבר) ממש קרוב אלינו"
#         },
#         {
#             "created_at": "2023-10-07T11:28:56.000Z",
#             "edit_history_tweet_ids": [
#                 "1710618205339738253"
#             ],
#             "id": "1710618205339738253",
#             "text": "מסוק עובר בעיר וכורז להשאר בבתים"
#         },
#         {
#             "created_at": "2023-10-07T11:26:27.000Z",
#             "edit_history_tweet_ids": [
#                 "1710617579042091233"
#             ],
#             "id": "1710617579042091233",
#             "text": "העדכון ממה שאנחנו מבינים זה שיש לחימה בבית העלמין בשדרות וסורקים את שאר העיר"
#         },
#         {
#             "created_at": "2023-10-07T11:18:06.000Z",
#             "edit_history_tweet_ids": [
#                 "1710615478383603919"
#             ],
#             "id": "1710615478383603919",
#             "text": "@eyal6699 גם ספציפית אתה לא נרתע מאלימות וזה עוזר"
#         },
#         {
#             "created_at": "2023-10-07T11:16:27.000Z",
#             "edit_history_tweet_ids": [
#                 "1710615063306899608"
#             ],
#             "id": "1710615063306899608",
#             "text": "אצלי: סבילות גבוהה לכאב, לפיתת מספריים אכזרית"
#         },
#         {
#             "created_at": "2023-10-07T11:15:32.000Z",
#             "edit_history_tweet_ids": [
#                 "1710614834071351681"
#             ],
#             "id": "1710614834071351681",
#             "text": "יאאלה, הפעלת הסחת דעת מכל הטירוף: שכל אחת ואחד יספרו את היתרון היחסי הכי משמעותי שלכם שיעזור לכם לנצח במכות"
#         },
#         {
#             "created_at": "2023-10-07T11:01:54.000Z",
#             "edit_history_tweet_ids": [
#                 "1710611402530939015"
#             ],
#             "id": "1710611402530939015",
#             "text": "זה שרק עכשיו, שבע שעות אחרי ההשתלטות על תחנת המשטרה בשדרות, אשכרה טיהרו אותה זו בעיקר סיבה לדאגה"
#         },
#         {
#             "created_at": "2023-10-07T10:27:33.000Z",
#             "edit_history_tweet_ids": [
#                 "1710602756946317709"
#             ],
#             "id": "1710602756946317709",
#             "text": "יאאלה זהו אפשר לחזלש"
#         },
#         {
#             "created_at": "2023-10-07T10:27:19.000Z",
#             "edit_history_tweet_ids": [
#                 "1710602700058992866"
#             ],
#             "id": "1710602700058992866",
#             "text": "ניצחון ישראלי ראשון היום https://t.co/7Ge1bIGytv"
#         },
#         {
#             "created_at": "2023-10-07T10:25:16.000Z",
#             "edit_history_tweet_ids": [
#                 "1710602182762836471"
#             ],
#             "id": "1710602182762836471",
#             "text": "לא יודע להסביר את התחושה למראה הדרך שאני הולך בה כל בוקר לשים את הילדים בגן הופכת לשדה מלחמה https://t.co/imDZMxB424"
#         },
#         {
#             "created_at": "2023-10-07T10:16:52.000Z",
#             "edit_history_tweet_ids": [
#                 "1710600067868954896"
#             ],
#             "id": "1710600067868954896",
#             "text": "@y_shif במיוחד כי זה הכי קל בעולם לדבר על שני הצדדים ובלשון רבים. תהיה אמיץ ותדבר על עצמך"
#         },
#         {
#             "created_at": "2023-10-07T10:12:11.000Z",
#             "edit_history_tweet_ids": [
#                 "1710598890448204004"
#             ],
#             "id": "1710598890448204004",
#             "text": "ראית יחיא עובד לנו https://t.co/1Xp2yZFRET"
#         },
#         {
#             "created_at": "2023-10-07T10:00:25.000Z",
#             "edit_history_tweet_ids": [
#                 "1710595928850153970"
#             ],
#             "id": "1710595928850153970",
#             "text": "בקבוצה של השכונה מדווחים על דפיקה על חלונות ושמיעת קול צעקה"
#         },
#         {
#             "created_at": "2023-10-07T09:24:06.000Z",
#             "edit_history_tweet_ids": [
#                 "1710586787872092489"
#             ],
#             "id": "1710586787872092489",
#             "text": "אמור להתראיין עוד מעט בגלי צהל למי שמעוניין"
#         },
#         {
#             "created_at": "2023-10-07T09:03:35.000Z",
#             "edit_history_tweet_ids": [
#                 "1710581624717369590"
#             ],
#             "id": "1710581624717369590",
#             "text": "הקפיצו למילואים את השכן. לפחות משהו זז"
#         },
#         {
#             "created_at": "2023-10-07T08:36:34.000Z",
#             "edit_history_tweet_ids": [
#                 "1710574828371976378"
#             ],
#             "id": "1710574828371976378",
#             "text": "אני באמצע שדה קרב עם בתי בת השנתיים ובני בן החצי שנה. אני, אישתי ומשפחתה. בתים בוערים על יושביהם. צבא של 70 מיליארד שקל שבקושי נוכח פה. ממשלת ימין מלא-מלא שלא אומרת דבר. רק אנחנו נעולים בתוך ממד עם סכין לחם שמצאנו במטבח."
#         },
#         {
#             "created_at": "2023-10-07T08:25:05.000Z",
#             "edit_history_tweet_ids": [
#                 "1710571939196981248"
#             ],
#             "id": "1710571939196981248",
#             "text": "הפקרות והפקרה. מקבלים זרם של הודעות ואין מה לעשות"
#         },
#         {
#             "created_at": "2023-10-07T08:19:10.000Z",
#             "edit_history_tweet_ids": [
#                 "1710570448398815635"
#             ],
#             "id": "1710570448398815635",
#             "text": "זה לא להאמין שעד עכשיו אין אפילו גורם מדיני שמנסה להעביר מידע בצורה מסודרת"
#         },
#         {
#             "created_at": "2023-10-07T08:10:31.000Z",
#             "edit_history_tweet_ids": [
#                 "1710568270611239137"
#             ],
#             "id": "1710568270611239137",
#             "text": "מצב העניינים: נגמר לניסן התמל. יש אצלנו בבית (אנחנו אצל ההורים של שיר שגרים ממול) אבל כרגע כמובן אי אפשר לצאת אז מסתדרים עם מה שיש"
#         },
#         {
#             "created_at": "2023-10-07T08:09:09.000Z",
#             "edit_history_tweet_ids": [
#                 "1710567927991161210"
#             ],
#             "id": "1710567927991161210",
#             "text": "RT @omerdank: לנשום עמוק\n===\nמדינת ישראל באירוע מסדר גודל של יום כיפור. מלבד הגנה וסיום האירוע בתוך מדינת ישראל, צריך להתארגן מחדש ולעבוד מ…"
#         },
#         {
#             "created_at": "2023-10-07T07:59:55.000Z",
#             "edit_history_tweet_ids": [
#                 "1710565603440824587"
#             ],
#             "id": "1710565603440824587",
#             "text": "וואו אני הולך לבזבז כל כך הרבה כסף באינטרנט כשזה ייגמר"
#         },
#         {
#             "created_at": "2023-10-07T07:47:34.000Z",
#             "edit_history_tweet_ids": [
#                 "1710562495750864956"
#             ],
#             "id": "1710562495750864956",
#             "text": "גדול השלום שאפילו בשעת מלחמה זקוק הוא לשלום https://t.co/qjZthGUhgs"
#         },
#         {
#             "created_at": "2023-10-07T07:40:52.000Z",
#             "edit_history_tweet_ids": [
#                 "1710560812245360927"
#             ],
#             "id": "1710560812245360927",
#             "text": "ההודעות מהקבוצות של חברים שלנו מכמה קיבוצים נוראיות."
#         },
#         {
#             "created_at": "2023-10-07T07:39:26.000Z",
#             "edit_history_tweet_ids": [
#                 "1710560447743643977"
#             ],
#             "id": "1710560447743643977",
#             "text": "הכלל שהכרזתי ואני אוכף באכזריות בממד: לא צועקים וואו, אמלה, אומייגד וכד'. אם יש מידע אומרים וגם מאיפה קיבלתם"
#         },
#         {
#             "created_at": "2023-10-07T07:37:41.000Z",
#             "edit_history_tweet_ids": [
#                 "1710560010608968173"
#             ],
#             "id": "1710560010608968173",
#             "text": "תראו, מאוד ברור שהמצב קשה ומפחיד. ובתוך זה ברור גם שחמאס עובד מאוד קשה עכשיו כדי להעצים את תחושת התבהלה והאימה. תנשמו עמוק ואל תעזרו להם."
#         },
#         {
#             "created_at": "2023-10-07T07:36:02.000Z",
#             "edit_history_tweet_ids": [
#                 "1710559594462752953"
#             ],
#             "id": "1710559594462752953",
#             "text": "@y_shif אני אוכל קובות סורי"
#         },
#         {
#             "created_at": "2023-10-07T07:32:27.000Z",
#             "edit_history_tweet_ids": [
#                 "1710558692880363820"
#             ],
#             "id": "1710558692880363820",
#             "text": "אנשים נורמליים: הפצת סרטוני סנאף רק מסייע לחמאס, צריך להפיץ מידע בדוק בלבד בצורה אחראית\nעניאל דמרם: אום נום נום מה אמרתם???"
#         },
#         {
#             "created_at": "2023-10-07T07:31:29.000Z",
#             "edit_history_tweet_ids": [
#                 "1710558448083988601"
#             ],
#             "id": "1710558448083988601",
#             "text": "@Jonathan_BY12 גגל"
#         },
#         {
#             "created_at": "2023-10-07T07:30:37.000Z",
#             "edit_history_tweet_ids": [
#                 "1710558231628501382"
#             ],
#             "id": "1710558231628501382",
#             "text": "שרמוטה של הלייקותתתת"
#         },
#         {
#             "created_at": "2023-10-07T07:30:23.000Z",
#             "edit_history_tweet_ids": [
#                 "1710558172623077665"
#             ],
#             "id": "1710558172623077665",
#             "text": "@arnondeg עם לא יכול להיות אוהב בארצו"
#         },
#         {
#             "created_at": "2023-10-07T07:28:26.000Z",
#             "edit_history_tweet_ids": [
#                 "1710557682334134492"
#             ],
#             "id": "1710557682334134492",
#             "text": "כן מדא אני יודע שאני או מינוס ושמאוד יעזור שאתרום דם, אבל ובכן יש כמה דברים שקצת מקשים עליי"
#         },
#         {
#             "created_at": "2023-10-07T07:26:46.000Z",
#             "edit_history_tweet_ids": [
#                 "1710557262958186736"
#             ],
#             "id": "1710557262958186736",
#             "text": "במרוכז לדיאמים מהסוג הזה: אני מקבל בדיוק את אותם הסרטונים כמוכם. אני לא מפרסם כי אין בזה שום ערך חוץ מלסייע לחמאס להפיץ פייק ותבהלה. ואני מבטיח שזה לא עוזר לאף אחד, בטח לא לנו"
#         },
#         {
#             "created_at": "2023-10-07T07:25:52.000Z",
#             "edit_history_tweet_ids": [
#                 "1710557035354267917"
#             ],
#             "id": "1710557035354267917",
#             "text": "חזקות מול החמאס https://t.co/7W08GZkc7f"
#         },
#         {
#             "created_at": "2023-10-07T07:21:17.000Z",
#             "edit_history_tweet_ids": [
#                 "1710555883015438402"
#             ],
#             "id": "1710555883015438402",
#             "text": "השאלה מה יקרה קודם: חמאסניקים ישתלטו לי על הבית ויהרגו אותנו או שאגיע ל10k עוקבים"
#         },
#         {
#             "created_at": "2023-10-07T07:14:35.000Z",
#             "edit_history_tweet_ids": [
#                 "1710554197018431948"
#             ],
#             "id": "1710554197018431948",
#             "text": "@MichalKatz6 הפעילו מזמן את מה שנקרא המערכים המסייעים. לא הפעילו את היחידות האופרטיביות של הגזרה פה. לפחות לא כאלו מהאוגדה שלי"
#         },
#         {
#             "created_at": "2023-10-07T07:08:34.000Z",
#             "edit_history_tweet_ids": [
#                 "1710552680739774705"
#             ],
#             "id": "1710552680739774705",
#             "text": "בשביל מה להפיץ את זה? זו הודעה לא רשמית שרצה בווצאפים כמו מליון אחרות. https://t.co/EkfGBzIOVD"
#         },
#         {
#             "created_at": "2023-10-07T07:07:49.000Z",
#             "edit_history_tweet_ids": [
#                 "1710552494722465946"
#             ],
#             "id": "1710552494722465946",
#             "text": "וגם אם יתמהמה https://t.co/tfyxFy4ZxU"
#         },
#         {
#             "created_at": "2023-10-07T07:05:15.000Z",
#             "edit_history_tweet_ids": [
#                 "1710551847285490068"
#             ],
#             "id": "1710551847285490068",
#             "text": "מה שאפשר לעשות https://t.co/rSTKMhNU22"
#         },
#         {
#             "created_at": "2023-10-07T07:05:09.000Z",
#             "edit_history_tweet_ids": [
#                 "1710551819905098162"
#             ],
#             "id": "1710551819905098162",
#             "text": "מדווחים בקבוצות השכונתיות שהצבא הגיע. היינו כחולמים."
#         },
#         {
#             "created_at": "2023-10-07T06:56:35.000Z",
#             "edit_history_tweet_ids": [
#                 "1710549667992264909"
#             ],
#             "id": "1710549667992264909",
#             "text": "עלה עכשיו אבל זה בעצם הציוץ הראשון שלי הבוקר"
#         },
#         {
#             "created_at": "2023-10-07T06:53:04.000Z",
#             "edit_history_tweet_ids": [
#                 "1710548782222299334"
#             ],
#             "id": "1710548782222299334",
#             "text": "עוד לא הפעילו מילואים אצלנו (היחידה שהאופרטיבי שלה הוא הגנה על הגבול והעוטף מחדירות). חשוב להסביר: מהרגע שגדוד מופעל יש בין 24 ל48 שעות עד שהוא נהיה אפקטיבי. כלומר כל העיכוב עכשיו מצטרף לזמן הזה עד שאשכרה יעבו כוחות. טירטף"
#         },
#         {
#             "created_at": "2023-10-07T06:48:24.000Z",
#             "edit_history_tweet_ids": [
#                 "1710547607372636252"
#             ],
#             "id": "1710547607372636252",
#             "text": "בוקר טוב. כבר כחצי שעה של מטחים בלי הפסקה. יירוטים לא נגמרים, חלקם מעלינו https://t.co/pc8VlxTObb"
#         },
#         {
#             "created_at": "2023-10-07T06:17:17.000Z",
#             "edit_history_tweet_ids": [
#                 "1710539776246382752"
#             ],
#             "id": "1710539776246382752",
#             "text": "כע, בעיקר לרכז מידע ולראות מי חמוש וזה\nhttps://t.co/X7ql3PtMW9"
#         },
#         {
#             "created_at": "2023-10-07T06:08:04.000Z",
#             "edit_history_tweet_ids": [
#                 "1710537454464184814"
#             ],
#             "id": "1710537454464184814",
#             "text": "אני מבוצר בממד בבית, מעבר למה שקורה בחדר או שאני שומע מסביב/רואה בחדשות אין לי איך לאמת או להפריך שמועות ודיווחים. זה רק עושה יותר לחץ וגם ככה נורא פה. די."
#         },
#         {
#             "created_at": "2023-10-07T06:06:56.000Z",
#             "edit_history_tweet_ids": [
#                 "1710537169406767293"
#             ],
#             "id": "1710537169406767293",
#             "text": "די.לשלוח.לי.תמונות.ולשאול.אם.זה.נכון"
#         },
#         {
#             "created_at": "2023-10-07T06:05:01.000Z",
#             "edit_history_tweet_ids": [
#                 "1710536690081632301"
#             ],
#             "id": "1710536690081632301",
#             "text": "פתחו כיתת כוננות ארעית של הרחוב וביקשו נציג מכל משפחה https://t.co/Q9JzBcj7De"
#         },
#         {
#             "created_at": "2023-10-07T05:52:00.000Z",
#             "edit_history_tweet_ids": [
#                 "1710533414565130685"
#             ],
#             "id": "1710533414565130685",
#             "text": "ההנחיות כרגע שעברו אלינו: כמה שיותר חושך, כמה שיותר שקט, הכל נעול ולהיות בחדר פנימי https://t.co/YrzimxACQN"
#         },
#         {
#             "created_at": "2023-10-07T05:49:26.000Z",
#             "edit_history_tweet_ids": [
#                 "1710532765395919244"
#             ],
#             "id": "1710532765395919244",
#             "text": "כולנו מחוברים לכל שביב של מקור מידע ובכן נמצאים בלב איזור הלחימה. או שלא חידשתם או שסתם עזרתם להפיץ תבהלה ופייק. חאלס."
#         },
#         {
#             "created_at": "2023-10-07T05:48:43.000Z",
#             "edit_history_tweet_ids": [
#                 "1710532585024106649"
#             ],
#             "id": "1710532585024106649",
#             "text": "עוזר ונחמד לקבל בווצאפ: הודעות חיזוק וחיבה\nלא עוזר: לקבל 'דיוווחם' שעיקרם שמועות שרותי השכנה העבירה לכם בקבוצה של הבניין"
#         },
#         {
#             "created_at": "2023-10-07T05:46:07.000Z",
#             "edit_history_tweet_ids": [
#                 "1710531932109312171"
#             ],
#             "id": "1710531932109312171",
#             "text": "@nitayp בוא נעשה מעגל שיח האם מדובר במבצע או במלחמה"
#         },
#         {
#             "created_at": "2023-10-07T05:45:50.000Z",
#             "edit_history_tweet_ids": [
#                 "1710531859828920510"
#             ],
#             "id": "1710531859828920510",
#             "text": "@naxmias אחות של שיר"
#         },
#         {
#             "created_at": "2023-10-07T05:42:59.000Z",
#             "edit_history_tweet_ids": [
#                 "1710531145840885995"
#             ],
#             "id": "1710531145840885995",
#             "text": "חמאסניקים 200 מטר אווירי מאיתנו אבל ניסן רעב מה נעשה https://t.co/g2pAtA4W0X"
#         },
#         {
#             "created_at": "2023-10-07T05:34:12.000Z",
#             "edit_history_tweet_ids": [
#                 "1710528935262380454"
#             ],
#             "id": "1710528935262380454",
#             "text": "@rsagiv01 גדוד מילואים לא אפקטיבי ב24-48 שעות הראשונות. אמור להיות אצלי במייל צו ושיחה מהמפקד שאומר שברגע שנרגע לעוף לבסיס. לחדירה הנוכחית זב כבר לא משנה אבל די ברור שאנחנו בהתחלה"
#         },
#         {
#             "created_at": "2023-10-07T05:32:47.000Z",
#             "edit_history_tweet_ids": [
#                 "1710528578884878481"
#             ],
#             "id": "1710528578884878481",
#             "text": "נו פאקינג שיט שרלוק https://t.co/hgL873mYhN"
#         },
#         {
#             "created_at": "2023-10-07T05:32:39.000Z",
#             "edit_history_tweet_ids": [
#                 "1710528543526879328"
#             ],
#             "id": "1710528543526879328",
#             "text": "זה ספין, הנוסח מרמז על עיבוי חמלים מודיעין וכאלה. איך יכול להיות שלא מכינים עתודות חי\"ר לעבות פה את הגבולות? אין כאן אף אחד https://t.co/RfYAjrsjMU"
#         },
#         {
#             "created_at": "2023-10-07T05:25:04.000Z",
#             "edit_history_tweet_ids": [
#                 "1710526634288095623"
#             ],
#             "id": "1710526634288095623",
#             "text": "מחבלים ברמי לוי, בספרייה העירונית, בגן ציבורי. אין פה באיזור צהל. בדיוק בשביל זה התאמנו ביחידת מילואים שלי. איך עוד אין צווי 8?????? בבקשה שמישהו יעשה משהו"
#         },
#         {
#             "created_at": "2023-10-07T05:18:24.000Z",
#             "edit_history_tweet_ids": [
#                 "1710524956738457958"
#             ],
#             "id": "1710524956738457958",
#             "text": "@nitayp אנע שומע פיצוצים מהגבול אבל תמבין למי פאקינג אכפת האירוע עכשיו הוא לא להפציץ בעזה אלא להגן על הגבול. אני אשכרה עם סכין לחם פה"
#         },
#         {
#             "created_at": "2023-10-07T05:17:17.000Z",
#             "edit_history_tweet_ids": [
#                 "1710524677746049098"
#             ],
#             "id": "1710524677746049098",
#             "text": "הייתי אמור לקבל כבר עשרה טלפונים שאומרים לי לעוף ליחידה ברגע שאפשר, לקחת נשק וציוד ואו לשמור על הגבול או לתפוס עמדה כאן בעיר או באחד היישובים. אלו תוכניות קיימות שהתאמנו להן. איך הן לא מופעלות???? החיים של הילדים שלי כל כך זניחים בעיניכם????"
#         },
#         {
#             "created_at": "2023-10-07T05:15:40.000Z",
#             "edit_history_tweet_ids": [
#                 "1710524268746887551"
#             ],
#             "id": "1710524268746887551",
#             "text": "ברור שהיה פה מחדל מחדלים. זה לא משנה עכשיו. מחבלים חמושים מסתובבים פה בכל בדרום. יש לצבא תוכניות בדיוק לרגעים כאלו. איך היא לא מופעלת? תקראו לנו כבר למילואים חבורה של מטומטמים"
#         },
#         {
#             "created_at": "2023-10-07T05:13:48.000Z",
#             "edit_history_tweet_ids": [
#                 "1710523801715314808"
#             ],
#             "id": "1710523801715314808",
#             "text": "תראו, יכול להיות שזה רק כי אני שדרותי היסטרי שמתבצר עם סכין מטבח בממד על הילדים אבל הנה מה שאני לא מבין: יש יחידות מילואים שלמות, למשל זו שאני משרת בה, שכל משימתן היא בדיוק רגעים כאלו ואמורות לרוץ לגבול  וליישובים ולהתמודד עם חדירה ונסיונות חדירה. איך עוד אין לי צו 8 במייל?"
#         },
#         {
#             "created_at": "2023-10-07T04:49:53.000Z",
#             "edit_history_tweet_ids": [
#                 "1710517780523475259"
#             ],
#             "id": "1710517780523475259",
#             "text": "סבב ביצורים אחרון https://t.co/dO9VgSzL6K"
#         },
#         {
#             "created_at": "2023-10-07T04:43:31.000Z",
#             "edit_history_tweet_ids": [
#                 "1710516177389178927"
#             ],
#             "id": "1710516177389178927",
#             "text": "התמונות שאתם רואים בחדשות הם ברחוב המקביל לנו. ליד הגן של נגב"
#         },
#         {
#             "created_at": "2023-10-07T04:40:06.000Z",
#             "edit_history_tweet_ids": [
#                 "1710515318295073191"
#             ],
#             "id": "1710515318295073191",
#             "text": "תגידו רגע אין צבא של 70 מיליארד שאמור לטפל באירועים כאלה?"
#         },
#         {
#             "created_at": "2023-10-07T04:38:45.000Z",
#             "edit_history_tweet_ids": [
#                 "1710514979068137950"
#             ],
#             "id": "1710514979068137950",
#             "text": "נגב בתגובה ראשונית לאירוע: רוצה בועות סבון"
#         },
#         {
#             "created_at": "2023-10-07T04:37:56.000Z",
#             "edit_history_tweet_ids": [
#                 "1710514775157854228"
#             ],
#             "id": "1710514775157854228",
#             "text": "סגרנו חלונות, החשכנו אורות והבאנו סכינים. שומעים ירי בחוץ"
#         },
#         {
#             "created_at": "2023-10-07T04:35:11.000Z",
#             "edit_history_tweet_ids": [
#                 "1710514079926739178"
#             ],
#             "id": "1710514079926739178",
#             "text": "מתבצרים בממד"
#         }
#     ],
#     "meta": {
#         "newest_id": "1710633227247841428",
#         "oldest_id": "1710514079926739178",
#         "result_count": 92
#     }
# }
# processing ('2023-10-07T12:30:01+00:00', '2023-10-07T20:30:00+00:00')
# 200
# {
#     "data": [
#         {
#             "created_at": "2023-10-07T19:43:48.000Z",
#             "edit_history_tweet_ids": [
#                 "1710742741766852886"
#             ],
#             "id": "1710742741766852886",
#             "text": "@dassyfr היו רגעים מאוד מפחידים, עכשיו ניסן עם כאבי שיניים שזה מפחיד אף יותר"
#         },
#         {
#             "created_at": "2023-10-07T19:34:12.000Z",
#             "edit_history_tweet_ids": [
#                 "1710740325826789456"
#             ],
#             "id": "1710740325826789456",
#             "text": "12 שעות הייתי נצור עם אשתי ילדיי, וזו הקקפוניה שעליה אני אמור לסמוך שתנהל את העניינים https://t.co/pAiIy21u55"
#         },
#         {
#             "created_at": "2023-10-07T18:55:15.000Z",
#             "edit_history_tweet_ids": [
#                 "1710730525361480044"
#             ],
#             "id": "1710730525361480044",
#             "text": "@FeldmanSaraa אנחנו כבר אחרי עיוני"
#         },
#         {
#             "created_at": "2023-10-07T18:40:02.000Z",
#             "edit_history_tweet_ids": [
#                 "1710726695324410178"
#             ],
#             "id": "1710726695324410178",
#             "text": "אפשר כבר שיקראו לי למילואים בבקשה?"
#         },
#         {
#             "created_at": "2023-10-07T18:23:09.000Z",
#             "edit_history_tweet_ids": [
#                 "1710722448167944314"
#             ],
#             "id": "1710722448167944314",
#             "text": "RT @NadavPerry: מה זה ממשלת חרום במתכונת ששת הימים?\nזה אומר שבן גביר ממשיך להיות אחראי על הביטחון הלאומי, סמוטריץ ממשיך לנהל את יו״ש, לוין…"
#         },
#         {
#             "created_at": "2023-10-07T18:20:05.000Z",
#             "edit_history_tweet_ids": [
#                 "1710721675963113643"
#             ],
#             "id": "1710721675963113643",
#             "text": "@zaratustrit זה ירדן השכן כבר סידר לנו"
#         },
#         {
#             "created_at": "2023-10-07T18:17:29.000Z",
#             "edit_history_tweet_ids": [
#                 "1710721019365756990"
#             ],
#             "id": "1710721019365756990",
#             "text": "ניסן התחיל לבכות ממש. לא נרגע. כנראה כאבי שיניים שמלווים אותו (בגל הנוכחי) כמה ימים. אין אקמול בבית של ההורים של שיר אז עשינו מבצע לחצייה שלי לבית ממול. הפרוצדורה: הארוס של גיסתי שאיתנו מלווה אותי ומתצפת ביציאה מהבית, משם אחד השכנים ובכניסה לבית שכן אחר. כוחותינו שבו בשלום+אקמול"
#         },
#         {
#             "created_at": "2023-10-07T17:51:15.000Z",
#             "edit_history_tweet_ids": [
#                 "1710714416700747838"
#             ],
#             "id": "1710714416700747838",
#             "text": "RT @Dvorit: למי אפשר להודיע על נצורים בקיבוץ בארי? מהבוקר: זוג קשישים חולים ובתם בממ\"ד, בלי מים, מזון וחשמל. סוללת הסל' של הבת אוזלת. לא מו…"
#         },
#         {
#             "created_at": "2023-10-07T17:49:58.000Z",
#             "edit_history_tweet_ids": [
#                 "1710714095006109947"
#             ],
#             "id": "1710714095006109947",
#             "text": "לא הבנתי מה יש לשמוח מממשלה כלשהי שכוללת את בן גביר וסמוטריץ' https://t.co/qBoAISTfOp"
#         },
#         {
#             "created_at": "2023-10-07T17:49:16.000Z",
#             "edit_history_tweet_ids": [
#                 "1710713919071752696"
#             ],
#             "id": "1710713919071752696",
#             "text": "@8989T_d_women לא"
#         },
#         {
#             "created_at": "2023-10-07T17:49:00.000Z",
#             "edit_history_tweet_ids": [
#                 "1710713850662732270"
#             ],
#             "id": "1710713850662732270",
#             "text": "חמאס זה נורא אבל ללעוס בפה פתוח זה יותר"
#         },
#         {
#             "created_at": "2023-10-07T17:47:46.000Z",
#             "edit_history_tweet_ids": [
#                 "1710713540510646278"
#             ],
#             "id": "1710713540510646278",
#             "text": "שומעים צרורות ירי. נשמע קרוב"
#         },
#         {
#             "created_at": "2023-10-07T16:51:22.000Z",
#             "edit_history_tweet_ids": [
#                 "1710699349569687991"
#             ],
#             "id": "1710699349569687991",
#             "text": "מה אני אומר: נגב אהובה שלי צריך לישון \nמה אני חושב: לללללכככככככייייי כככככבבבבבבבבררררררר לישוןןןןןןןןןןן"
#         },
#         {
#             "created_at": "2023-10-07T16:50:05.000Z",
#             "edit_history_tweet_ids": [
#                 "1710699025370898852"
#             ],
#             "id": "1710699025370898852",
#             "text": "צהל אולי השיג שליטה על מחנה רעים אבל אבל אני טרם השגתי שליטה על ההרדמות"
#         },
#         {
#             "created_at": "2023-10-07T16:21:40.000Z",
#             "edit_history_tweet_ids": [
#                 "1710691872958533636"
#             ],
#             "id": "1710691872958533636",
#             "text": "@omerjy אני חושב (שוב, בנפרד לגבי עמדתי שמודה שעוד לא גיבשתי) שזה ילך למבצע פירוז במקרה הטוב או כיבוש במקרה הרע"
#         },
#         {
#             "created_at": "2023-10-07T16:10:14.000Z",
#             "edit_history_tweet_ids": [
#                 "1710688998312567153"
#             ],
#             "id": "1710688998312567153",
#             "text": "@DanaGat1 על פניו חלק מהמבצע של חמאס היה התקפה על מוצבים ובעיקר על אוגדת עזה. זה הסיט את הסדרניקים למצב הגנה ומאוד הקשה על לנהל את הלחימה (כי האוגדה לא תפקדה). פלוס היה פחות סדכ כי העבירו ליו\"ש"
#         },
#         {
#             "created_at": "2023-10-07T16:08:55.000Z",
#             "edit_history_tweet_ids": [
#                 "1710688665792352731"
#             ],
#             "id": "1710688665792352731",
#             "text": "RT @amit1tomer: עזבו בשורות קונקרטיות, 12 שעות לתוך הגיהנום הזה עדיין לא שמענו מארבעת השרים שאחראים על השירותים החברתיים שלנו אף מילה.\n\nשרת…"
#         },
#         {
#             "created_at": "2023-10-07T16:01:38.000Z",
#             "edit_history_tweet_ids": [
#                 "1710686832457838723"
#             ],
#             "id": "1710686832457838723",
#             "text": "מערכה רב זירתית על מלא. אחד נרגע השנייה מתחילה"
#         },
#         {
#             "created_at": "2023-10-07T15:59:23.000Z",
#             "edit_history_tweet_ids": [
#                 "1710686265929015653"
#             ],
#             "id": "1710686265929015653",
#             "text": "בוויכוח בין פיד ימין לשמאל לגבי מי אשם, הממשלה או הצבא, אני איפשהו באמצע. האחריות היא קודם כל על רהמ ששלט פה 99 אחוז מהזמן ב14 שנה האחרונות ועל הממשלה.בטח על הממשלה הכהניסטית הנוכחית. אבל האחריות היא גם על הצבא ועל קריסת המערכות הטוטאלית שראינו היום. https://t.co/IghpVUBmsk"
#         },
#         {
#             "created_at": "2023-10-07T15:55:44.000Z",
#             "edit_history_tweet_ids": [
#                 "1710685346038468770"
#             ],
#             "id": "1710685346038468770",
#             "text": "מצב העניינים פה: מנסה להרדים בו זמנית שני תינוקות בממ\"ד וזה הולך בדיוק כמו שאתם חושבים"
#         },
#         {
#             "created_at": "2023-10-07T15:54:56.000Z",
#             "edit_history_tweet_ids": [
#                 "1710685147828220086"
#             ],
#             "id": "1710685147828220086",
#             "text": "לצורך העניין, אני לא חושב שפעולה קרקעית ברצועה היא בכלל עניין שנתון לבחירת הממשלה עכשיו"
#         },
#         {
#             "created_at": "2023-10-07T15:53:50.000Z",
#             "edit_history_tweet_ids": [
#                 "1710684867573190793"
#             ],
#             "id": "1710684867573190793",
#             "text": "אני חושב שבלי קשר למה נחשוב על זה, אם הסיפור הזה נסגר כמו עוד סבב/מבצע וואטאבר יהיה מרי אזרחי רחב היקף וחוצה מחנות"
#         },
#         {
#             "created_at": "2023-10-07T15:53:16.000Z",
#             "edit_history_tweet_ids": [
#                 "1710684728234279225"
#             ],
#             "id": "1710684728234279225",
#             "text": "זה מרגיש שצהל וביבי בוויב שתמונות של בום בום גדול של חיל האוויר והודעות 'חמאס ספג מכה קשה' הן איזשהו מענה למה שקורה וקרה ואם כן הם חיים בסרט אבל מה סרט"
#         },
#         {
#             "created_at": "2023-10-07T15:45:12.000Z",
#             "edit_history_tweet_ids": [
#                 "1710682698279162007"
#             ],
#             "id": "1710682698279162007",
#             "text": "@yairwein ארוחה במסעדה לבחירת המנצח שלפחות לא בשבוע הקרוב"
#         },
#         {
#             "created_at": "2023-10-07T15:39:58.000Z",
#             "edit_history_tweet_ids": [
#                 "1710681378541506941"
#             ],
#             "id": "1710681378541506941",
#             "text": "ההצעה של לפיד היא מסוג הדברים שאין צורך לטרוח לגבש עליהן דעה כי אין שום סיכוי שיקרו. נתניהו לא יזרוק את בן גביר וסמוטריץ' אפשר להתקדם"
#         },
#         {
#             "created_at": "2023-10-07T15:15:18.000Z",
#             "edit_history_tweet_ids": [
#                 "1710675174062751899"
#             ],
#             "id": "1710675174062751899",
#             "text": "עדכון: שכן שם את נפשו בכפו ופשוט שם לנו את התמל בדלת. תודה ירדןןןן"
#         },
#         {
#             "created_at": "2023-10-07T15:04:30.000Z",
#             "edit_history_tweet_ids": [
#                 "1710672453964349819"
#             ],
#             "id": "1710672453964349819",
#             "text": "@netagrinfas134r יש קבט שמעבר ללהגיד שוב ושוב אין יציאה מבתים לא עזר"
#         },
#         {
#             "created_at": "2023-10-07T15:01:17.000Z",
#             "edit_history_tweet_ids": [
#                 "1710671643834450411"
#             ],
#             "id": "1710671643834450411",
#             "text": "טוב, זה כבר לא מצחיק: אנחנו זקוקים לעזרה. אנחנו סגורים בבית בלי תמל ובלי חלב או כל אוכל אחר רלוונטי לתינוק. הכל נגמר. יש תמל בבית שלנו ממול אבל אסור לצאת ואנחנו מפחדים מאש ידידותית יותר או פחות. כבר 11 שעות שאנחנו פה ואף אחד לא עוזר לנו."
#         },
#         {
#             "created_at": "2023-10-07T14:22:31.000Z",
#             "edit_history_tweet_ids": [
#                 "1710661890139992371"
#             ],
#             "id": "1710661890139992371",
#             "text": "תמונת מצב: אירוע התמל הופך להיות עניין. נגמר בבית של ההורים כל התחליפים האפשריים וקונספט השאיבה מיצה את עצמו. לפני הלילה נהיה חייבים לתת גיחה לבית שלנו ממול"
#         },
#         {
#             "created_at": "2023-10-07T13:44:46.000Z",
#             "edit_history_tweet_ids": [
#                 "1710652388808294733"
#             ],
#             "id": "1710652388808294733",
#             "text": "ברוך הבא ברוצ'קה, בוא לקפה https://t.co/MibweTTuJT"
#         },
#         {
#             "created_at": "2023-10-07T13:44:29.000Z",
#             "edit_history_tweet_ids": [
#                 "1710652317349908673"
#             ],
#             "id": "1710652317349908673",
#             "text": "המק\"כ המזדיין הזה פה מהבוקר. איך עוד לא הורידו אותו כוסראבק ערס https://t.co/dHIzfGG4QX"
#         },
#         {
#             "created_at": "2023-10-07T13:39:41.000Z",
#             "edit_history_tweet_ids": [
#                 "1710651111319715954"
#             ],
#             "id": "1710651111319715954",
#             "text": "למי שתהה איך נראים פאתי השכונה שלי. אגב מימין זה החומוס של טחינה https://t.co/dHIzfGG4QX"
#         },
#         {
#             "created_at": "2023-10-07T13:34:37.000Z",
#             "edit_history_tweet_ids": [
#                 "1710649834842079609"
#             ],
#             "id": "1710649834842079609",
#             "text": "חברה מהעבודה ביקשה ממני לשתף אז כנראה שלג'יט https://t.co/viqdgknNri"
#         },
#         {
#             "created_at": "2023-10-07T13:30:03.000Z",
#             "edit_history_tweet_ids": [
#                 "1710648684323520945"
#             ],
#             "id": "1710648684323520945",
#             "text": "בדיוק. תמיכה בזמן מלחמה היא עניין כלל מערכתי, לא רק עניין צבאי https://t.co/8LJGYHGo4l"
#         },
#         {
#             "created_at": "2023-10-07T13:29:12.000Z",
#             "edit_history_tweet_ids": [
#                 "1710648473014432055"
#             ],
#             "id": "1710648473014432055",
#             "text": "הקבינט הסתיים לפני עשרים דקות. למה אין מסיבת עיתונאים מסודרת עם תשובות ותמונת מצב? יש אלפי תושבים שנמצאים עכשיו תחת שליטת החמאס או באיזור לחימה פעיל מולם (היוש). המינימום זה לתת תשובות וכיוון"
#         },
#         {
#             "created_at": "2023-10-07T13:24:48.000Z",
#             "edit_history_tweet_ids": [
#                 "1710647365504241702"
#             ],
#             "id": "1710647365504241702",
#             "text": "כמובן שפיד קובידבעים מצטיין בהפצת הפייק של חמאס"
#         },
#         {
#             "created_at": "2023-10-07T13:23:59.000Z",
#             "edit_history_tweet_ids": [
#                 "1710647160125940029"
#             ],
#             "id": "1710647160125940029",
#             "text": "אנחנו יותר מ10 שעות מתחילת הלחימה ומידת השליטה של ישראל בדרום הארץ הוא כזה שאנחנו לא יכולים לצאת לרגע מהבית להביא תמ\"ל שנמצא ממול"
#         },
#         {
#             "created_at": "2023-10-07T13:16:33.000Z",
#             "edit_history_tweet_ids": [
#                 "1710645289659342862"
#             ],
#             "id": "1710645289659342862",
#             "text": "מסימני התקופה: אחת השכנות כותבת אזהרה שטורקים את הדלת כדי שלא נבהל"
#         },
#         {
#             "created_at": "2023-10-07T13:14:41.000Z",
#             "edit_history_tweet_ids": [
#                 "1710644815946236101"
#             ],
#             "id": "1710644815946236101",
#             "text": "לא נולד המשבר  שהצמרת הצהלית בעבר ובהווה לא תנצל למלחמות שיבוצים https://t.co/NAKjydCMsb"
#         },
#         {
#             "created_at": "2023-10-07T13:11:50.000Z",
#             "edit_history_tweet_ids": [
#                 "1710644102511939692"
#             ],
#             "id": "1710644102511939692",
#             "text": "@omercookss לא"
#         },
#         {
#             "created_at": "2023-10-07T13:09:00.000Z",
#             "edit_history_tweet_ids": [
#                 "1710643386787479986"
#             ],
#             "id": "1710643386787479986",
#             "text": "אשכרה מחלל שבת על למה טיבי ועודה לא מגנים איני יכול עוד"
#         },
#         {
#             "created_at": "2023-10-07T13:06:41.000Z",
#             "edit_history_tweet_ids": [
#                 "1710642803724714458"
#             ],
#             "id": "1710642803724714458",
#             "text": "כן מטומטם דעתם של טיבי ועודה זה מה שקריטי עכשיו"
#         },
#         {
#             "created_at": "2023-10-07T13:05:23.000Z",
#             "edit_history_tweet_ids": [
#                 "1710642477366149504"
#             ],
#             "id": "1710642477366149504",
#             "text": "לקח לו קצת פחות מ3 שעות לעבור מ'אבל אשמים אנחנו' לציד המכשפות הרגיל https://t.co/cP4l6YRCv9"
#         },
#         {
#             "created_at": "2023-10-07T13:02:01.000Z",
#             "edit_history_tweet_ids": [
#                 "1710641631131582557"
#             ],
#             "id": "1710641631131582557",
#             "text": "הו כן https://t.co/09W76GMwB7"
#         },
#         {
#             "created_at": "2023-10-07T12:59:42.000Z",
#             "edit_history_tweet_ids": [
#                 "1710641049175990523"
#             ],
#             "id": "1710641049175990523",
#             "text": "עוד רעש בגג"
#         },
#         {
#             "created_at": "2023-10-07T12:49:35.000Z",
#             "edit_history_tweet_ids": [
#                 "1710638502927307088"
#             ],
#             "id": "1710638502927307088",
#             "text": "@AdiAdipaz או פשוט לחזור למספר המדווח"
#         },
#         {
#             "created_at": "2023-10-07T12:48:31.000Z",
#             "edit_history_tweet_ids": [
#                 "1710638232117907696"
#             ],
#             "id": "1710638232117907696",
#             "text": "עדכון לוהט מהגזרה https://t.co/9W8pI5vd3W"
#         },
#         {
#             "created_at": "2023-10-07T12:48:30.000Z",
#             "edit_history_tweet_ids": [
#                 "1710638230167597100"
#             ],
#             "id": "1710638230167597100",
#             "text": "חם לי https://t.co/VvT986SAUN"
#         },
#         {
#             "created_at": "2023-10-07T12:40:35.000Z",
#             "edit_history_tweet_ids": [
#                 "1710636236858105905"
#             ],
#             "id": "1710636236858105905",
#             "text": "סיכום עד כה: שמענו רעש חשוד בגג והתבצרנו. הייתה לחימה עם מחבלים בגג ברחוב סמוך. הגיעו אנשים לבושים כחיילים לא מזמן, כולנו חושבים שהם אכן חיילים אבל איך לדעת אז אנחנו בממד"
#         },
#         {
#             "created_at": "2023-10-07T12:38:23.000Z",
#             "edit_history_tweet_ids": [
#                 "1710635683788824724"
#             ],
#             "id": "1710635683788824724",
#             "text": "חם לי https://t.co/xLonC9FTCo"
#         },
#         {
#             "created_at": "2023-10-07T12:37:24.000Z",
#             "edit_history_tweet_ids": [
#                 "1710635434055709107"
#             ],
#             "id": "1710635434055709107",
#             "text": "הקונצנזוס בקבוצת שכנים הוא שבחוץ זה צהל, אבל אין איך לוודא אז אנחנו בממד"
#         }
#     ],
#     "meta": {
#         "newest_id": "1710742741766852886",
#         "oldest_id": "1710635434055709107",
#         "result_count": 51
#     }
# }
# processing ('2023-10-07T20:30:01+00:00', '2023-10-08T04:30:00+00:00')
# 200
# {
#     "data": [
#         {
#             "created_at": "2023-10-08T04:23:11.000Z",
#             "edit_history_tweet_ids": [
#                 "1710873448895963488"
#             ],
#             "id": "1710873448895963488",
#             "text": "קצת אוויר https://t.co/BGglxKy9Le"
#         },
#         {
#             "created_at": "2023-10-08T04:04:36.000Z",
#             "edit_history_tweet_ids": [
#                 "1710868773903716462"
#             ],
#             "id": "1710868773903716462",
#             "text": "כבר יותר מ24 שעות שאנחנו נצורים בבתים https://t.co/aZPZWnzQzN"
#         },
#         {
#             "created_at": "2023-10-08T03:51:00.000Z",
#             "edit_history_tweet_ids": [
#                 "1710865349359337689"
#             ],
#             "id": "1710865349359337689",
#             "text": "סיכום הלילה: מלא צבע אדום, קרבות בעיר כל הזמן (מניח שבעיקר סביב תחנת המשטרה, פשוט מאוד קרוב אלינו). נגב הלכה מכות עם המזרון ולא ברור מי המנצח ומי המפסיד. מחכה שיאשרו לצאת מהבית בשביל לצאת למילואים https://t.co/eDAHYXAgbj"
#         },
#         {
#             "created_at": "2023-10-08T03:46:28.000Z",
#             "edit_history_tweet_ids": [
#                 "1710864209792094332"
#             ],
#             "id": "1710864209792094332",
#             "text": "יןם יומי"
#         },
#         {
#             "created_at": "2023-10-08T03:46:23.000Z",
#             "edit_history_tweet_ids": [
#                 "1710864186509504540"
#             ],
#             "id": "1710864186509504540",
#             "text": "הבסט קייס סנריו, אם נתעלם מהשלכות מוסריות, הוא יוש\"יזציה של עזה. כיבוש ושליטה מלאים בשטח וכוחות בסד\"כ פסיכי (26 גדודים). זה לא טרום ההתנתקות אלא אירוע אחר לגמרי שאני לא ממש מבין איך מישהו חושב שאפשרי, ולו ברמה הטכנית. וגם אחריו, כמו שאנחנו רואים ביו\"ש, זה ממש לא מונע טבח וטרור"
#         },
#         {
#             "created_at": "2023-10-08T03:43:30.000Z",
#             "edit_history_tweet_ids": [
#                 "1710863464661487877"
#             ],
#             "id": "1710863464661487877",
#             "text": "זאת טענה ביזארית שמניחה שציר הזמן ועקומת השיפור של האויב (שקרתה גם בימי גוש קטיף) לא תקפה כשאזרחינו נמצאים בלב שטח האויב. במילים אחרות: אני מפחד לדמיין מה היה קורה אם בימינו היה לחמאס מטרות כ\"כ זמינות כמו ילדים שנוסעים בעזה כל בוקר לבצפר\nhttps://t.co/T4wIg8ElMc"
#         },
#         {
#             "created_at": "2023-10-07T22:29:28.000Z",
#             "edit_history_tweet_ids": [
#                 "1710784434415280415"
#             ],
#             "id": "1710784434415280415",
#             "text": "בעיקר לא ברור לי הבוז של מתנחלים לדם מתנחלים. כאילו, כשטבחו ללא הפסקה באזרחי גוש קטיף זה היה פחות נורא? https://t.co/mCsBCXqEPu"
#         },
#         {
#             "created_at": "2023-10-07T21:57:36.000Z",
#             "edit_history_tweet_ids": [
#                 "1710776415673618442"
#             ],
#             "id": "1710776415673618442",
#             "text": "פיצוץ אחושרמוטה. בקטע שהרעיד את הבית"
#         },
#         {
#             "created_at": "2023-10-07T21:55:31.000Z",
#             "edit_history_tweet_ids": [
#                 "1710775888323719608"
#             ],
#             "id": "1710775888323719608",
#             "text": "@NuritPeleg @HauzmanOfir @Shtrudel_yann בתקווה שברגע שיתייצב קצת יהיה למי להפנות. כרגע כולם שאובים למצב הלחימה בעיר"
#         },
#         {
#             "created_at": "2023-10-07T21:53:24.000Z",
#             "edit_history_tweet_ids": [
#                 "1710775358700601706"
#             ],
#             "id": "1710775358700601706",
#             "text": "אני לא הולך לישון הלילה, הא?"
#         },
#         {
#             "created_at": "2023-10-07T21:38:48.000Z",
#             "edit_history_tweet_ids": [
#                 "1710771683441668112"
#             ],
#             "id": "1710771683441668112",
#             "text": "שוב גל צרורות ירי"
#         },
#         {
#             "created_at": "2023-10-07T21:30:04.000Z",
#             "edit_history_tweet_ids": [
#                 "1710769484070305871"
#             ],
#             "id": "1710769484070305871",
#             "text": "לאדע, מדווחים שתפסו את המחבל שהסתובב כאן אבל אני עדיין שומע ירי"
#         },
#         {
#             "created_at": "2023-10-07T21:27:47.000Z",
#             "edit_history_tweet_ids": [
#                 "1710768910344012278"
#             ],
#             "id": "1710768910344012278",
#             "text": "שוב צרורות ירי. הדיבור הוא שזה מהטנק"
#         },
#         {
#             "created_at": "2023-10-07T21:20:17.000Z",
#             "edit_history_tweet_ids": [
#                 "1710767024840782287"
#             ],
#             "id": "1710767024840782287",
#             "text": "שמענו עכשיו כמה צרורות של ירי ממש קרוב אלינו לבית"
#         },
#         {
#             "created_at": "2023-10-07T20:33:32.000Z",
#             "edit_history_tweet_ids": [
#                 "1710755258597609813"
#             ],
#             "id": "1710755258597609813",
#             "text": "@Jeronimo_ לחץ צבאי ואזרחי על החמאס"
#         },
#         {
#             "created_at": "2023-10-07T20:32:27.000Z",
#             "edit_history_tweet_ids": [
#                 "1710754985317695501"
#             ],
#             "id": "1710754985317695501",
#             "text": "@Jeronimo_ הקו של משפחת גולדין היה הפוך. התנגדו לתת מחבלים"
#         }
#     ],
#     "meta": {
#         "newest_id": "1710873448895963488",
#         "oldest_id": "1710754985317695501",
#         "result_count": 16
#     }
# }
# processing ('2023-10-08T04:30:01+00:00', '2023-10-08T12:30:00+00:00')
# 200
# {
#     "data": [
#         {
#             "created_at": "2023-10-08T10:26:53.000Z",
#             "edit_history_tweet_ids": [
#                 "1710964979481117175"
#             ],
#             "id": "1710964979481117175",
#             "text": "אפשר שכבר יסגרו את הגדר תודה???"
#         },
#         {
#             "created_at": "2023-10-08T08:20:26.000Z",
#             "edit_history_tweet_ids": [
#                 "1710933154993742277"
#             ],
#             "id": "1710933154993742277",
#             "text": "אנחנו בסדר"
#         },
#         {
#             "created_at": "2023-10-08T07:21:46.000Z",
#             "edit_history_tweet_ids": [
#                 "1710918389986697394"
#             ],
#             "id": "1710918389986697394",
#             "text": "https://t.co/OVDozCikag"
#         },
#         {
#             "created_at": "2023-10-08T06:38:16.000Z",
#             "edit_history_tweet_ids": [
#                 "1710907446158377259"
#             ],
#             "id": "1710907446158377259",
#             "text": "כאילו ספציפית אני שוביסט אז זה יותר לבוא ולקחת תיק כבד אחושרמוטה ו/או מע\"ד אבל הבנתם תנקודה )))::::"
#         },
#         {
#             "created_at": "2023-10-08T06:35:41.000Z",
#             "edit_history_tweet_ids": [
#                 "1710906796246708380"
#             ],
#             "id": "1710906796246708380",
#             "text": "אני לא מהאו\"ם. יש לי ביקורת מכאן עד הירח על הכיבוש, על המדיניות הישראלית בעזה ובוודאי על הממשלה הנוכחית. אבל אתמול הסתובבו בשכונה שלנו חמושים שבאו כדי לרצוח את הילדה שלי. ואם יש לי הזדמנות לקחת נשק, להגיע לגבול ולעצור אותם מלהגיע שוב - אני בא הכי מהר שאני יכול. כזה אני, מוטה. https://t.co/t9mJk1Ii7H"
#         },
#         {
#             "created_at": "2023-10-08T06:24:41.000Z",
#             "edit_history_tweet_ids": [
#                 "1710904023874707687"
#             ],
#             "id": "1710904023874707687",
#             "text": "אגב, בתחנת המשטרה בשדרות היה כזה מוזיאון של שרידי רקטות מכל הסבבים השונים אז גם הלכה היסטוריה"
#         },
#         {
#             "created_at": "2023-10-08T06:22:50.000Z",
#             "edit_history_tweet_ids": [
#                 "1710903559368163488"
#             ],
#             "id": "1710903559368163488",
#             "text": "לשיר חשוב להבהיר שטכנית זו לא נשכונה שלי כי המשטרה היא בכזה נק' גבול בין 2 שכונות"
#         },
#         {
#             "created_at": "2023-10-08T06:22:29.000Z",
#             "edit_history_tweet_ids": [
#                 "1710903472865108055"
#             ],
#             "id": "1710903472865108055",
#             "text": "@SharonaMazalian אנחנו בסדר, גרים במרחק מסוים מהעסק אז זה בעיקר לשמוע את הירי והבומים"
#         },
#         {
#             "created_at": "2023-10-08T06:21:47.000Z",
#             "edit_history_tweet_ids": [
#                 "1710903294388777076"
#             ],
#             "id": "1710903294388777076",
#             "text": "במרוכז לשאלות לגבי #עניי_עירך - תודה על הרצון להתגייס וכמובן שגם אני רוצה להתחיל לשנע סיוע לאיפה שצריך. כרגע כולנו מחכים שהלחימה בעיר תסתיים כי עד אז אי אפשר להגיע לאף אחד וכל העיר מסתגרת"
#         },
#         {
#             "created_at": "2023-10-08T06:16:50.000Z",
#             "edit_history_tweet_ids": [
#                 "1710902052136550541"
#             ],
#             "id": "1710902052136550541",
#             "text": "פיצוצים חזקים. לאוזניי האחושלוקי לא מקצועיות נשמע כמו ירי טנק"
#         },
#         {
#             "created_at": "2023-10-08T06:15:13.000Z",
#             "edit_history_tweet_ids": [
#                 "1710901642101452840"
#             ],
#             "id": "1710901642101452840",
#             "text": "מסתכל על הצילום הזה בטלגרם של עמית סגל ופתאום מבין שזו לא סוריה או תימן - זו השכונה שלי https://t.co/i1vzxBtnqZ"
#         },
#         {
#             "created_at": "2023-10-08T06:08:38.000Z",
#             "edit_history_tweet_ids": [
#                 "1710899987171672325"
#             ],
#             "id": "1710899987171672325",
#             "text": "הסיפור של הנתק מצהל הוא בלתי נסבל. אתמול שמענו רעשים חשודים בגג, דיווחנו למוקד, הגיעו חיילים ופשוט לא יכלנו לדעת אם אלו חיילים או חאמסניקים מחופשיפ כי אין עם מי לדבר. https://t.co/WUKr2yJMGr"
#         },
#         {
#             "created_at": "2023-10-08T06:07:15.000Z",
#             "edit_history_tweet_ids": [
#                 "1710899640697082055"
#             ],
#             "id": "1710899640697082055",
#             "text": "RT @bokeralmog: שימו לה לקריאה החריגה הזאת של הנהלת קיבוץ כפר עזה: \n״אנחנו, הנהלת קיבוץ כפר עזה מבקשים מיידית איש קשר מצהל. לא מוכנים להיות…"
#         },
#         {
#             "created_at": "2023-10-08T05:51:33.000Z",
#             "edit_history_tweet_ids": [
#                 "1710895687003513220"
#             ],
#             "id": "1710895687003513220",
#             "text": "RT @DanaGat1: בוקר טוב\n\nנפתחה ברמת גן נקודת איסוף לדברים בסיסיים למפוני בארי\nצריכים הכל- \nמוצרי הגיינה \nבגדים לילדים ולמבוגרים בכל המידות…"
#         },
#         {
#             "created_at": "2023-10-08T05:50:07.000Z",
#             "edit_history_tweet_ids": [
#                 "1710895328352739710"
#             ],
#             "id": "1710895328352739710",
#             "text": "@eranwinter איך אתה יוצא? אסור לצאת"
#         },
#         {
#             "created_at": "2023-10-08T05:28:05.000Z",
#             "edit_history_tweet_ids": [
#                 "1710889783415783493"
#             ],
#             "id": "1710889783415783493",
#             "text": "RT @DanaGat1: חשוב חשוב חשוב בבקשה שתפו.\nאתמול משפחת גת (מצורפת תמונה) נחטפה מקיבוץ בארי.\nאלון והבת הצליחו לברוח מהרכב וחזרו לקיבוץ\nהמידע ה…"
#         },
#         {
#             "created_at": "2023-10-08T04:58:45.000Z",
#             "edit_history_tweet_ids": [
#                 "1710882399758766550"
#             ],
#             "id": "1710882399758766550",
#             "text": "זה פשוט לקחת את מטרות הסבבים הגנריים ולהגדיל בשקל תשעים https://t.co/YJkkCmbhuR"
#         },
#         {
#             "created_at": "2023-10-08T04:49:07.000Z",
#             "edit_history_tweet_ids": [
#                 "1710879976076046832"
#             ],
#             "id": "1710879976076046832",
#             "text": "שמעו לאדע נגמרו הרעיונות להעביר תזמן אני פשוט עושה שיט https://t.co/4bsV523cC4"
#         },
#         {
#             "created_at": "2023-10-08T04:37:28.000Z",
#             "edit_history_tweet_ids": [
#                 "1710877042768572448"
#             ],
#             "id": "1710877042768572448",
#             "text": "כבר 25 שעות שהחיים התהפכו עלינו. טורי ב @YediotAhronot. תודה ל @HadarGil על הבמה https://t.co/t9NNlur4Ol"
#         }
#     ],
#     "meta": {
#         "newest_id": "1710964979481117175",
#         "oldest_id": "1710877042768572448",
#         "result_count": 19
#     }
# }
# processing ('2023-10-08T12:30:01+00:00', '2023-10-08T20:30:00+00:00')
# 429
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# /var/folders/5k/16q8nbv50r3f3t_4f4v9x7900000gq/T/ipykernel_2661/2042348560.py in <cell line: 0>()
#       8 for time in times:
#       9     print(f"processing {time}")
# ---> 10     response = main(time[0], time[1], user_id)
#      11     df = pd.DataFrame(response['data'])
#      12     df.to_csv(f"id{user_id}_{time[0][:19]}_{time[1][:19]}.csv")
#
# /var/folders/5k/16q8nbv50r3f3t_4f4v9x7900000gq/T/ipykernel_2661/3624156814.py in main(start_time, end_time, user_id)
#      57     url = create_url(user_id)
#      58     params = get_params(start_time, end_time)
# ---> 59     json_response = connect_to_endpoint(url, params)
#      60     print(json.dumps(json_response, indent=4, sort_keys=True, ensure_ascii=False))
#      61     return json_response
#
# /var/folders/5k/16q8nbv50r3f3t_4f4v9x7900000gq/T/ipykernel_2661/3624156814.py in connect_to_endpoint(url, params)
#      46     print(response.status_code)
#      47     if response.status_code != 200:
# ---> 48         raise Exception(
#      49             "Request returned an error: {} {}".format(
#      50                 response.status_code, response.text
#
# Exception: Request returned an error: 429 {"title":"Too Many Requests","detail":"Too Many Requests","type":"about:blank","status":429}

# %%
# Read in all csv files in path, concatenate and save final
# set path to directory containing csv files
# TODO: replace with path where scrapes are saved
path = ""

# create empty list to store dataframes
dfs = []

# loop through each file in the directory
for file in os.listdir(path):
    # check if file is a csv file
    if file.endswith(".csv"):
        # read csv file into a dataframe
        df = pd.read_csv(os.path.join(path, file))
        # append dataframe to list of dataframes
        dfs.append(df)

# concatenate all dataframes into one
final_df = pd.concat(dfs)

# save final dataframe to csv file
final_df.to_csv("final.csv", index=False)
